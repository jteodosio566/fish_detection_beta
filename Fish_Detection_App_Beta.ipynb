# %% [markdown]
# <a href="https://colab.research.google.com/github/jteodosio566/fish_detection_beta/blob/main/Fish_Detection_App_Beta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Setup**
#
# Clone repo, install dependencies and check PyTorch and GPU.

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt  # install dependencies

import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 1.9.0+cu102 (Tesla T4)

# %% [markdown]
# ### **Unpack our zip folder containing the dataset**

# %%
# !unzip -q ../train_data.zip -d ../

# %% [markdown]
# ### **3. Train**

# %%
# Train YOLOv5s on our train data for 60 epochs
# !python train.py --img 640 --batch 16 --epochs 60 --data custom_data.yaml --weights yolov5s.pt --cache
# Out:
# ...
# 100% 755k/755k [00:00<00:00, 23.5MB/s]
# train: weights=yolov5s.pt, cfg=, data=custom_data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=60, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, entity=None, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias=latest, local_rank=-1, freeze=0, patience=100
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v5.0-408-g2317f86 torch 1.9.0+cu102 CUDA:0 (Tesla T4, 15109.75MB)
#
# ...

# %% [markdown]
# ### **4. Test our model on videos**

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source ../video_test_1.mp4
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=../video_test_1.mp4, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False
# YOLOv5 🚀 v5.0-408-g2317f86 torch 1.9.0+cu102 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7053910 parameters, 0 gradients, 16.3 GFLOPs
# video 1/1 (1/797) /content/yolov5/../video_test_1.mp4: 320x640 9 fishs, Done. (0.011s)
# video 1/1 (2/797) /content/yolov5/../video_test_1.mp4: 320x640 9 fishs, Done. (0.010s)
# video 1/1 (3/797) /content/yolov5/../video_test_1.mp4: 320x640 9 fishs, Done. (0.010s)
# video 1/1 (4/797) /content/yolov5/../video_test_1.mp4: 320x640 9 fishs, Done. (0.011s)
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source ../video_test_2.mp4
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=../video_test_2.mp4, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False
# YOLOv5 🚀 v5.0-408-g2317f86 torch 1.9.0+cu102 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7053910 parameters, 0 gradients, 16.3 GFLOPs
# video 1/1 (1/849) /content/yolov5/../video_test_2.mp4: 320x640 6 fishs, Done. (0.011s)
# video 1/1 (2/849) /content/yolov5/../video_test_2.mp4: 320x640 6 fishs, Done. (0.010s)
# video 1/1 (3/849) /content/yolov5/../video_test_2.mp4: 320x640 7 fishs, Done. (0.010s)
# video 1/1 (4/849) /content/yolov5/../video_test_2.mp4: 320x640 7 fishs, Done. (0.010s)
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source ../video_test_3.mp4
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=../video_test_3.mp4, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False
# YOLOv5 🚀 v5.0-408-g2317f86 torch 1.9.0+cu102 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7053910 parameters, 0 gradients, 16.3 GFLOPs
# video 1/1 (1/655) /content/yolov5/../video_test_3.mp4: 320x640 9 fishs, Done. (0.012s)
# video 1/1 (2/655) /content/yolov5/../video_test_3.mp4: 320x640 9 fishs, Done. (0.010s)
# video 1/1 (3/655) /content/yolov5/../video_test_3.mp4: 320x640 9 fishs, Done. (0.010s)
# video 1/1 (4/655) /content/yolov5/../video_test_3.mp4: 320x640 9 fishs, Done. (0.010s)
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source ../video_test_4.mp4
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=../video_test_4.mp4, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False
# YOLOv5 🚀 v5.0-408-g2317f86 torch 1.9.0+cu102 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7053910 parameters, 0 gradients, 16.3 GFLOPs
# video 1/1 (1/440) /content/yolov5/../video_test_4.mp4: 320x640 4 fishs, Done. (0.012s)
# video 1/1 (2/440) /content/yolov5/../video_test_4.mp4: 320x640 4 fishs, Done. (0.010s)
# video 1/1 (3/440) /content/yolov5/../video_test_4.mp4: 320x640 4 fishs, Done. (0.010s)
# video 1/1 (4/440) /content/yolov5/../video_test_4.mp4: 320x640 4 fishs, Done. (0.010s)
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source ../video_test_5.mp4
# Out:
# Streaming output truncated to the last 5000 lines.
# video 1/1 (10/5007) /content/yolov5/../video_test_5.mp4: 320x640 7 fishs, Done. (0.010s)
# video 1/1 (11/5007) /content/yolov5/../video_test_5.mp4: 320x640 7 fishs, Done. (0.010s)
# video 1/1 (12/5007) /content/yolov5/../video_test_5.mp4: 320x640 8 fishs, Done. (0.010s)
# video 1/1 (13/5007) /content/yolov5/../video_test_5.mp4: 320x640 8 fishs, Done. (0.010s)
# video 1/1 (14/5007) /content/yolov5/../video_test_5.mp4: 320x640 7 fishs, Done. (0.010s)
# video 1/1 (15/5007) /content/yolov5/../video_test_5.mp4: 320x640 8 fishs, Done. (0.010s)
# video 1/1 (16/5007) /content/yolov5/../video_test_5.mp4: 320x640 7 fishs, Done. (0.010s)
# video 1/1 (17/5007) /content/yolov5/../video_test_5.mp4: 320x640 7 fishs, Done. (0.010s)
# video 1/1 (18/5007) /content/yolov5/../video_test_5.mp4: 320x640 7 fishs, Done. (0.011s)
# video 1/1 (19/5007) /content/yolov5/../video_test_5.mp4: 320x640 7 fishs, Done. (0.010s)
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source ../image_test_1.jpg
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=../image_test_1.jpg, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False
# YOLOv5 🚀 v5.0-408-g2317f86 torch 1.9.0+cu102 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7053910 parameters, 0 gradients, 16.3 GFLOPs
# image 1/1 /content/yolov5/../image_test_1.jpg: 320x640 5 fishs, Done. (0.012s)
# Results saved to runs/detect/exp14
# Done. (0.285s)

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source ../image_test_2.jpg
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=../image_test_2.jpg, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False
# YOLOv5 🚀 v5.0-408-g2317f86 torch 1.9.0+cu102 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7053910 parameters, 0 gradients, 16.3 GFLOPs
# image 1/1 /content/yolov5/../image_test_2.jpg: 384x640 8 fishs, Done. (0.012s)
# Results saved to runs/detect/exp15
# Done. (0.316s)

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source ../image_test_3.jpg
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=../image_test_3.jpg, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False
# YOLOv5 🚀 v5.0-408-g2317f86 torch 1.9.0+cu102 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7053910 parameters, 0 gradients, 16.3 GFLOPs
# image 1/1 /content/yolov5/../image_test_3.jpg: 480x640 15 fishs, Done. (0.013s)
# Results saved to runs/detect/exp16
# Done. (0.179s)

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source ../image_test_4.jpg
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=../image_test_4.jpg, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False
# YOLOv5 🚀 v5.0-408-g2317f86 torch 1.9.0+cu102 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7053910 parameters, 0 gradients, 16.3 GFLOPs
# image 1/1 /content/yolov5/../image_test_4.jpg: 480x640 6 fishs, Done. (0.013s)
# Results saved to runs/detect/exp17
# Done. (0.154s)

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source ../image_test_5.jpg
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=../image_test_5.jpg, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False
# YOLOv5 🚀 v5.0-408-g2317f86 torch 1.9.0+cu102 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7053910 parameters, 0 gradients, 16.3 GFLOPs
# image 1/1 /content/yolov5/../image_test_5.jpg: 352x640 5 fishs, Done. (0.012s)
# Results saved to runs/detect/exp18
# Done. (0.188s)

# %% [markdown]
# ### **We save our weights**

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# %cp /content/yolov5/runs/train/exp/weights/best.pt /content/gdrive/MyDrive/
